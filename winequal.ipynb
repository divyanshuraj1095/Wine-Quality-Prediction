# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Data Collection

# %%
wine_dataset=pd.read_csv('winequality-red.csv')

# %%
wine_dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
wine_dataset.shape
# Out:
# (1599, 12)

# %%
wine_dataset.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
wine_dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Data Analysis and visualization

# %%
### number of values for each quality
sns.catplot(x='quality', data = wine_dataset, kind = 'count' )

# %%
## volatile acidity vs quality(inversely proportional)
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'volatile acidity', data = wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
## citric acid vs quality(directly proportional)
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'citric acid', data = wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %% [markdown]
# ### Correlation

# %%
correlation = wine_dataset.corr()

# %%
# constructing a heat map to understand te=he correlation between the columns
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar = True, square = True, fmt = '.1f', annot = True, annot_kws={'size': 8}, cmap = 'Blues')
# Out:
# <Axes: >

# %% [markdown]
# ### Data Preprocessing

# %%
#separate the data and label
X= wine_dataset.drop('quality', axis =1)
print(X)
# Out:
#       fixed acidity  volatile acidity  citric acid  ...    pH  sulphates  alcohol
# 0               7.4             0.700         0.00  ...  3.51       0.56      9.4
# 1               7.8             0.880         0.00  ...  3.20       0.68      9.8
# 2               7.8             0.760         0.04  ...  3.26       0.65      9.8
# 3              11.2             0.280         0.56  ...  3.16       0.58      9.8
# 4               7.4             0.700         0.00  ...  3.51       0.56      9.4
# ...             ...               ...          ...  ...   ...        ...      ...
# 1594            6.2             0.600         0.08  ...  3.45       0.58     10.5
# 1595            5.9             0.550         0.10  ...  3.52       0.76     11.2
# 1596            6.3             0.510         0.13  ...  3.42       0.75     11.0
# 1597            5.9             0.645         0.12  ...  3.57       0.71     10.2
# ...

# %% [markdown]
# ### Label Binarisation

# %%
Y = wine_dataset['quality'].apply(lambda y_value: 1 if y_value >=7 else 0)

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# ### Train and Test split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %% [markdown]
# ### Model Training: Random Forest Classifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ### Model Evaluation : Accuracy Score

# %%
#Accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print("accuracy_score of the model: ",test_data_accuracy)
# Out:
# accuracy_score of the model:  0.925

# %% [markdown]
# ### Building a predictive system

# %%
input_data = (7.3,0.65,0.0,1.2,0.065,15.0,21.0,0.9946,3.39,0.47,10.0)

#changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshape the data as we are predicting the label for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if(prediction[0]==1):
    print("The is a good quality !!")
else:
    print('The quality is bad !!')
# Out:
# [1]
# The is a good quality !!
# e:\ML-DL projects\WineQualityPred\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
